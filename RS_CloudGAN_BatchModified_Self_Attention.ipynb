# %%
# example of pix2pix gan for satellite to map image-to-image translation
import numpy as np
from keras.optimizers import Adam
from keras.initializers import RandomNormal
from keras.models import *
from keras.layers import *
import os
import matplotlib.pyplot as plt
from PIL import Image

# %% [markdown]
# # Define Losses

# %%
input_size = 512 # 128x128x3 images (training_set)
batch_size = 1

# %%
# defining other metrics:
def psnr(y_true,y_pred):
    return tf.image.psnr(y_true,y_pred,1.0)
def ssim(y_true,y_pred):
    return tf.image.ssim(y_true,y_pred,1.0)

# %%
# load and prepare training images
def load_real_samples(root_dir):
    cloud_imgdir = root_dir+"/cloudy_image"
    clear_imgdir = root_dir+"/ground_truth"
    X1 = []
    X2 = []
    for i,j in zip(os.listdir(cloud_imgdir),os.listdir(clear_imgdir)):
        os.chdir(cloud_imgdir)
        X1.append(np.array(Image.open(i),dtype = 'float32')[:,:,:3]/255)
        os.chdir(clear_imgdir)
        X2.append(np.array(Image.open(j),dtype = 'float32')[:,:,:3]/255)
    return [X1, X2]

# %%
root_dir = "C:/Users/ArrunPersonal/Codes/ISRO_GAN/RICE Dataset/RICE1_ThinCloud/RICE1Train"
dataset = np.array(load_real_samples(root_dir))
print("Loaded", dataset[0].shape, dataset[1].shape)

# %% [markdown]
# ## PatchGAN Discriminator

# %%
def define_discriminator(image_shape):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# source image input
	in_src_image = Input(shape=image_shape)
	# target image input
	in_target_image = Input(shape=image_shape)
	# concatenate images channel-wise
	merged = Concatenate()([in_src_image, in_target_image])
	# C64
	d = Conv2D(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(merged)
	d = LeakyReLU(alpha=0.2)(d)
	# C128
	d = Conv2D(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C256
	d = Conv2D(256, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C512
	d = Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# second last output layer
	d = Conv2D(512, (4,4), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# patch output
	d = Conv2D(1, (4,4), padding='same', kernel_initializer=init)(d)
	patch_out = Activation('sigmoid')(d)
	# define model
	model = Model([in_src_image, in_target_image], patch_out)
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt, loss_weights=[0.5])
	return model
 
# define image shape
image_shape = (input_size,input_size,3)
# create the model
model = define_discriminator(image_shape)
# summarize the model
model.summary()

# %% [markdown]
# ## RS_Cloud GAN Proposed Encoder

# %%
def encoder_block(input_features,num_filters, filter_size=[3,5,7]):
    conv1_1 = Conv2D(num_filters,filter_size[0], padding = 'same',activation = 'relu')(input_features)
    conv1_2 = Conv2D(num_filters,filter_size[1], padding = 'same',activation = 'relu')(input_features)
    conv1_3 = Conv2D(num_filters,filter_size[2], padding = 'same',activation = 'relu')(input_features)

    concat_12 = Concatenate()([conv1_1,conv1_2])
    concat_13 = Concatenate()([conv1_2,conv1_3])
    concat_23 = Concatenate()([conv1_1,conv1_3])

    conv2_1 = Conv2D(num_filters,3, padding = 'same',activation = 'relu')(concat_12)
    conv2_2 = Conv2D(num_filters,3, padding = 'same',activation = 'relu')(concat_23)
    conv2_3 = Conv2D(num_filters,3, padding = 'same',activation = 'relu')(concat_13)

    concat_123 = Concatenate()([conv2_1,conv2_2,conv2_3])
    conv_fin = Conv2D(num_filters,3, padding = 'same',activation = 'relu')(concat_123)
    maxpool_fin = MaxPool2D(2)(conv_fin)
    return maxpool_fin

# %%
def decoder_block(input_layer,skip_connection, num_filters,filter_size=[3,5,7]):
    convt1_1 = Conv2DTranspose(num_filters, filter_size[0], padding = 'same',activation = 'relu')(input_layer)
    convt1_2 = Conv2DTranspose(num_filters, filter_size[1], padding = 'same',activation = 'relu')(input_layer)
    convt1_3 = Conv2DTranspose(num_filters, filter_size[2], padding = 'same',activation = 'relu')(input_layer)

    concat_12 = Concatenate()([convt1_1,convt1_2])
    concat_13 = Concatenate()([convt1_2,convt1_3])
    concat_23 = Concatenate()([convt1_1,convt1_3])

    conv2_1 = Conv2D(num_filters,3, padding = 'same',activation = 'relu')(concat_12)
    conv2_2 = Conv2D(num_filters,3, padding = 'same',activation = 'relu')(concat_23)
    conv2_3 = Conv2D(num_filters,3, padding = 'same',activation = 'relu')(concat_13)

    concat_123 = Concatenate()([conv2_1,conv2_2,conv2_3,skip_connection])
    conv_fin = Conv2D(num_filters,3, padding = 'same',activation = 'relu')(concat_123)
    upsampling_fin = UpSampling2D(2)(conv_fin)
    
    return upsampling_fin

# %%
def bottleneck(input_layer,drop = 0.2):
    feature_layer = Conv2D(512,3,padding = 'same',activation = 'linear')(input_layer)
    attention_layer = Conv2D(512,3,padding = 'same',activation = 'sigmoid')(feature_layer)
    new_input_features = MultiHeadAttention(num_heads=3, key_dim=3, attention_axes=(2, 3))(input_layer,attention_layer)
    
    batch_norma = BatchNormalization()(new_input_features)
    if(drop):
        drop = Dropout(drop)(batch_norma)
        return drop
    return batch_norma

# %% [markdown]
# ## 3 Layer

# %%
input_layer = Input((512,512,3))
e1 = encoder_block(input_layer,32)
e2 = encoder_block(e1,64)
e3 = encoder_block(e2,128)
b = bottleneck(e3)
d1 = decoder_block(b,e3,64)
d2 = decoder_block(d1,e2,32)
d3 = decoder_block(d2,e1,3)

CR_Net = Model(inputs = input_layer, outputs = d3)
CR_Net.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 32  4736        ['input_3[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 512, 512, 32  7808        ['input_3[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 512, 512, 32  11648       ['input_3[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 512, 512, 64  0           ['conv2d_6[0][0]',
#                                 )                                 'conv2d_7[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 64  0           ['conv2d_6[0][0]',
#                                 )                                 'conv2d_8[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 512, 512, 64  0           ['conv2d_7[0][0]',
#                                 )                                 'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 512, 512, 32  18464       ['concatenate_1[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 512, 512, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 512, 512, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 512, 512, 96  0           ['conv2d_9[0][0]',
#                                 )                                 'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 512, 512, 32  27680       ['concatenate_4[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 32  0           ['conv2d_12[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 64  100416      ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 64  165952      ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 64  247872      ['max_pooling2d[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_13[0][0]',
#                                 8)                                'conv2d_14[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_13[0][0]',
#                                 8)                                'conv2d_15[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_14[0][0]',
#                                 8)                                'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_5[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_6[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 256, 256, 19  0           ['conv2d_16[0][0]',
#                                 2)                                'conv2d_17[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 64  110656      ['concatenate_8[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64  0          ['conv2d_19[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 12  401536      ['max_pooling2d_1[0][0]']
#                                 8)
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 12  663680      ['max_pooling2d_1[0][0]']
#                                 8)
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 12  991360      ['max_pooling2d_1[0][0]']
#                                 8)
#
#  concatenate_9 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_20[0][0]',
#                                 6)                                'conv2d_21[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_20[0][0]',
#                                 6)                                'conv2d_22[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_21[0][0]',
#                                 6)                                'conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_9[0][0]']
#                                 8)
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_11[0][0]']
#                                 8)
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_10[0][0]']
#                                 8)
#
#  concatenate_12 (Concatenate)   (None, 128, 128, 38  0           ['conv2d_23[0][0]',
#                                 4)                                'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 12  442496      ['concatenate_12[0][0]']
#                                 8)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 3)    3459        ['max_pooling2d_2[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 64, 64, 3)   12          ['conv2d_27[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 64, 64, 3)    0           ['batch_normalization_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 64, 64, 64)  9472        ['dropout[0][0]']
#  ose)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 64, 64, 64)  15616       ['dropout[0][0]']
#  spose)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 64)  23296       ['dropout[0][0]']
#  spose)
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 128)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_transpose_1[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 64, 64, 128)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_transpose_2[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 64, 64, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_transpose_2[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_13[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_15[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_14[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 64, 64, 320)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_29[0][0]',
#                                                                   'conv2d_30[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 64)   184384      ['concatenate_16[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 128, 128, 64  0           ['conv2d_31[0][0]']
#                                 )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 32  100384     ['up_sampling2d[0][0]']
#  spose)                         )
#
#  conv2d_transpose_4 (Conv2DTran  (None, 128, 128, 32  165920     ['up_sampling2d[0][0]']
#  spose)                         )
#
#  conv2d_transpose_5 (Conv2DTran  (None, 128, 128, 32  247840     ['up_sampling2d[0][0]']
#  spose)                         )
#
#  concatenate_17 (Concatenate)   (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_transpose_4[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 128, 128, 64  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_transpose_5[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 128, 128, 64  0           ['conv2d_transpose_4[0][0]',
#                                 )                                 'conv2d_transpose_5[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_17[0][0]']
#                                 )
#
#  conv2d_33 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_19[0][0]']
#                                 )
#
#  conv2d_34 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_18[0][0]']
#                                 )
#
#  concatenate_20 (Concatenate)   (None, 128, 128, 16  0           ['conv2d_32[0][0]',
#                                 0)                                'conv2d_33[0][0]',
#                                                                   'conv2d_34[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 128, 128, 32  46112       ['concatenate_20[0][0]']
#                                 )
#
#  up_sampling2d_1 (UpSampling2D)  (None, 256, 256, 32  0          ['conv2d_35[0][0]']
#                                 )
#
#  conv2d_transpose_6 (Conv2DTran  (None, 256, 256, 3)  4707       ['up_sampling2d_1[0][0]']
#  spose)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 256, 256, 3)  7779       ['up_sampling2d_1[0][0]']
#  spose)
#
#  conv2d_transpose_8 (Conv2DTran  (None, 256, 256, 3)  11619      ['up_sampling2d_1[0][0]']
#  spose)
#
#  concatenate_21 (Concatenate)   (None, 256, 256, 6)  0           ['conv2d_transpose_6[0][0]',
#                                                                   'conv2d_transpose_7[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 256, 256, 6)  0           ['conv2d_transpose_6[0][0]',
#                                                                   'conv2d_transpose_8[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 256, 256, 6)  0           ['conv2d_transpose_7[0][0]',
#                                                                   'conv2d_transpose_8[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 256, 256, 3)  165         ['concatenate_21[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 256, 256, 3)  165         ['concatenate_23[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 256, 256, 3)  165         ['concatenate_22[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 256, 256, 41  0           ['conv2d_36[0][0]',
#                                 )                                 'conv2d_37[0][0]',
#                                                                   'conv2d_38[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 256, 256, 3)  1110        ['concatenate_24[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 512, 512, 3)  0          ['conv2d_39[0][0]']
#
# ==================================================================================================
# Total params: 5,436,701
# Trainable params: 5,436,695
# Non-trainable params: 6
# __________________________________________________________________________________________________

# %% [markdown]
# ## 4 Layer

# %%
input_layer = Input((512,512,3))
e1 = encoder_block(input_layer,32)
e2 = encoder_block(e1,64)
e3 = encoder_block(e2,128)
e4 = encoder_block(e3,256)
b = bottleneck(e4)
d1 = decoder_block(b,e4,128)
d2 = decoder_block(d1,e3,64)
d3 = decoder_block(d2,e2,32)
d4 = decoder_block(d3,e1,3)

CR_Net = Model(inputs = input_layer, outputs = d4)
CR_Net.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_4 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_40 (Conv2D)             (None, 512, 512, 32  4736        ['input_4[0][0]']
#                                 )
#
#  conv2d_41 (Conv2D)             (None, 512, 512, 32  7808        ['input_4[0][0]']
#                                 )
#
#  conv2d_42 (Conv2D)             (None, 512, 512, 32  11648       ['input_4[0][0]']
#                                 )
#
#  concatenate_25 (Concatenate)   (None, 512, 512, 64  0           ['conv2d_40[0][0]',
#                                 )                                 'conv2d_41[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 512, 512, 64  0           ['conv2d_40[0][0]',
#                                 )                                 'conv2d_42[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 512, 512, 64  0           ['conv2d_41[0][0]',
#                                 )                                 'conv2d_42[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 512, 512, 32  18464       ['concatenate_25[0][0]']
#                                 )
#
#  conv2d_44 (Conv2D)             (None, 512, 512, 32  18464       ['concatenate_27[0][0]']
#                                 )
#
#  conv2d_45 (Conv2D)             (None, 512, 512, 32  18464       ['concatenate_26[0][0]']
#                                 )
#
#  concatenate_28 (Concatenate)   (None, 512, 512, 96  0           ['conv2d_43[0][0]',
#                                 )                                 'conv2d_44[0][0]',
#                                                                   'conv2d_45[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 512, 512, 32  27680       ['concatenate_28[0][0]']
#                                 )
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 256, 256, 32  0          ['conv2d_46[0][0]']
#                                 )
#
#  conv2d_47 (Conv2D)             (None, 256, 256, 64  100416      ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_48 (Conv2D)             (None, 256, 256, 64  165952      ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_49 (Conv2D)             (None, 256, 256, 64  247872      ['max_pooling2d_3[0][0]']
#                                 )
#
#  concatenate_29 (Concatenate)   (None, 256, 256, 12  0           ['conv2d_47[0][0]',
#                                 8)                                'conv2d_48[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 256, 256, 12  0           ['conv2d_47[0][0]',
#                                 8)                                'conv2d_49[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 256, 256, 12  0           ['conv2d_48[0][0]',
#                                 8)                                'conv2d_49[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_29[0][0]']
#                                 )
#
#  conv2d_51 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_31[0][0]']
#                                 )
#
#  conv2d_52 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_30[0][0]']
#                                 )
#
#  concatenate_32 (Concatenate)   (None, 256, 256, 19  0           ['conv2d_50[0][0]',
#                                 2)                                'conv2d_51[0][0]',
#                                                                   'conv2d_52[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 256, 256, 64  110656      ['concatenate_32[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 128, 128, 64  0          ['conv2d_53[0][0]']
#                                 )
#
#  conv2d_54 (Conv2D)             (None, 128, 128, 12  401536      ['max_pooling2d_4[0][0]']
#                                 8)
#
#  conv2d_55 (Conv2D)             (None, 128, 128, 12  663680      ['max_pooling2d_4[0][0]']
#                                 8)
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 12  991360      ['max_pooling2d_4[0][0]']
#                                 8)
#
#  concatenate_33 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_54[0][0]',
#                                 6)                                'conv2d_55[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_54[0][0]',
#                                 6)                                'conv2d_56[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_55[0][0]',
#                                 6)                                'conv2d_56[0][0]']
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_33[0][0]']
#                                 8)
#
#  conv2d_58 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_35[0][0]']
#                                 8)
#
#  conv2d_59 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_34[0][0]']
#                                 8)
#
#  concatenate_36 (Concatenate)   (None, 128, 128, 38  0           ['conv2d_57[0][0]',
#                                 4)                                'conv2d_58[0][0]',
#                                                                   'conv2d_59[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 128, 128, 12  442496      ['concatenate_36[0][0]']
#                                 8)
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_60[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 64, 64, 256)  1605888     ['max_pooling2d_5[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 64, 64, 256)  2654464     ['max_pooling2d_5[0][0]']
#
#  conv2d_63 (Conv2D)             (None, 64, 64, 256)  3965184     ['max_pooling2d_5[0][0]']
#
#  concatenate_37 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_61[0][0]',
#                                                                   'conv2d_62[0][0]']
#
#  concatenate_39 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_61[0][0]',
#                                                                   'conv2d_63[0][0]']
#
#  concatenate_38 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_62[0][0]',
#                                                                   'conv2d_63[0][0]']
#
#  conv2d_64 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_37[0][0]']
#
#  conv2d_65 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_39[0][0]']
#
#  conv2d_66 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_38[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 64, 64, 768)  0           ['conv2d_64[0][0]',
#                                                                   'conv2d_65[0][0]',
#                                                                   'conv2d_66[0][0]']
#
#  conv2d_67 (Conv2D)             (None, 64, 64, 256)  1769728     ['concatenate_40[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_67[0][0]']
#
#  conv2d_68 (Conv2D)             (None, 32, 32, 3)    6915        ['max_pooling2d_6[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 32, 32, 3)   12          ['conv2d_68[0][0]']
#  rmalization)
#
#  dropout_1 (Dropout)            (None, 32, 32, 3)    0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_9 (Conv2DTran  (None, 32, 32, 128)  18944      ['dropout_1[0][0]']
#  spose)
#
#  conv2d_transpose_10 (Conv2DTra  (None, 32, 32, 128)  31232      ['dropout_1[0][0]']
#  nspose)
#
#  conv2d_transpose_11 (Conv2DTra  (None, 32, 32, 128)  46592      ['dropout_1[0][0]']
#  nspose)
#
#  concatenate_41 (Concatenate)   (None, 32, 32, 256)  0           ['conv2d_transpose_9[0][0]',
#                                                                   'conv2d_transpose_10[0][0]']
#
#  concatenate_43 (Concatenate)   (None, 32, 32, 256)  0           ['conv2d_transpose_9[0][0]',
#                                                                   'conv2d_transpose_11[0][0]']
#
#  concatenate_42 (Concatenate)   (None, 32, 32, 256)  0           ['conv2d_transpose_10[0][0]',
#                                                                   'conv2d_transpose_11[0][0]']
#
#  conv2d_69 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_41[0][0]']
#
#  conv2d_70 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_43[0][0]']
#
#  conv2d_71 (Conv2D)             (None, 32, 32, 128)  295040      ['concatenate_42[0][0]']
#
#  concatenate_44 (Concatenate)   (None, 32, 32, 640)  0           ['conv2d_69[0][0]',
#                                                                   'conv2d_70[0][0]',
#                                                                   'conv2d_71[0][0]',
#                                                                   'max_pooling2d_6[0][0]']
#
#  conv2d_72 (Conv2D)             (None, 32, 32, 128)  737408      ['concatenate_44[0][0]']
#
#  up_sampling2d_3 (UpSampling2D)  (None, 64, 64, 128)  0          ['conv2d_72[0][0]']
#
#  conv2d_transpose_12 (Conv2DTra  (None, 64, 64, 64)  401472      ['up_sampling2d_3[0][0]']
#  nspose)
#
#  conv2d_transpose_13 (Conv2DTra  (None, 64, 64, 64)  663616      ['up_sampling2d_3[0][0]']
#  nspose)
#
#  conv2d_transpose_14 (Conv2DTra  (None, 64, 64, 64)  991296      ['up_sampling2d_3[0][0]']
#  nspose)
#
#  concatenate_45 (Concatenate)   (None, 64, 64, 128)  0           ['conv2d_transpose_12[0][0]',
#                                                                   'conv2d_transpose_13[0][0]']
#
#  concatenate_47 (Concatenate)   (None, 64, 64, 128)  0           ['conv2d_transpose_12[0][0]',
#                                                                   'conv2d_transpose_14[0][0]']
#
#  concatenate_46 (Concatenate)   (None, 64, 64, 128)  0           ['conv2d_transpose_13[0][0]',
#                                                                   'conv2d_transpose_14[0][0]']
#
#  conv2d_73 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_45[0][0]']
#
#  conv2d_74 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_47[0][0]']
#
#  conv2d_75 (Conv2D)             (None, 64, 64, 64)   73792       ['concatenate_46[0][0]']
#
#  concatenate_48 (Concatenate)   (None, 64, 64, 320)  0           ['conv2d_73[0][0]',
#                                                                   'conv2d_74[0][0]',
#                                                                   'conv2d_75[0][0]',
#                                                                   'max_pooling2d_5[0][0]']
#
#  conv2d_76 (Conv2D)             (None, 64, 64, 64)   184384      ['concatenate_48[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 128, 128, 64  0          ['conv2d_76[0][0]']
#                                 )
#
#  conv2d_transpose_15 (Conv2DTra  (None, 128, 128, 32  100384     ['up_sampling2d_4[0][0]']
#  nspose)                        )
#
#  conv2d_transpose_16 (Conv2DTra  (None, 128, 128, 32  165920     ['up_sampling2d_4[0][0]']
#  nspose)                        )
#
#  conv2d_transpose_17 (Conv2DTra  (None, 128, 128, 32  247840     ['up_sampling2d_4[0][0]']
#  nspose)                        )
#
#  concatenate_49 (Concatenate)   (None, 128, 128, 64  0           ['conv2d_transpose_15[0][0]',
#                                 )                                 'conv2d_transpose_16[0][0]']
#
#  concatenate_51 (Concatenate)   (None, 128, 128, 64  0           ['conv2d_transpose_15[0][0]',
#                                 )                                 'conv2d_transpose_17[0][0]']
#
#  concatenate_50 (Concatenate)   (None, 128, 128, 64  0           ['conv2d_transpose_16[0][0]',
#                                 )                                 'conv2d_transpose_17[0][0]']
#
#  conv2d_77 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_49[0][0]']
#                                 )
#
#  conv2d_78 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_51[0][0]']
#                                 )
#
#  conv2d_79 (Conv2D)             (None, 128, 128, 32  18464       ['concatenate_50[0][0]']
#                                 )
#
#  concatenate_52 (Concatenate)   (None, 128, 128, 16  0           ['conv2d_77[0][0]',
#                                 0)                                'conv2d_78[0][0]',
#                                                                   'conv2d_79[0][0]',
#                                                                   'max_pooling2d_4[0][0]']
#
#  conv2d_80 (Conv2D)             (None, 128, 128, 32  46112       ['concatenate_52[0][0]']
#                                 )
#
#  up_sampling2d_5 (UpSampling2D)  (None, 256, 256, 32  0          ['conv2d_80[0][0]']
#                                 )
#
#  conv2d_transpose_18 (Conv2DTra  (None, 256, 256, 3)  4707       ['up_sampling2d_5[0][0]']
#  nspose)
#
#  conv2d_transpose_19 (Conv2DTra  (None, 256, 256, 3)  7779       ['up_sampling2d_5[0][0]']
#  nspose)
#
#  conv2d_transpose_20 (Conv2DTra  (None, 256, 256, 3)  11619      ['up_sampling2d_5[0][0]']
#  nspose)
#
#  concatenate_53 (Concatenate)   (None, 256, 256, 6)  0           ['conv2d_transpose_18[0][0]',
#                                                                   'conv2d_transpose_19[0][0]']
#
#  concatenate_55 (Concatenate)   (None, 256, 256, 6)  0           ['conv2d_transpose_18[0][0]',
#                                                                   'conv2d_transpose_20[0][0]']
#
#  concatenate_54 (Concatenate)   (None, 256, 256, 6)  0           ['conv2d_transpose_19[0][0]',
#                                                                   'conv2d_transpose_20[0][0]']
#
#  conv2d_81 (Conv2D)             (None, 256, 256, 3)  165         ['concatenate_53[0][0]']
#
#  conv2d_82 (Conv2D)             (None, 256, 256, 3)  165         ['concatenate_55[0][0]']
#
#  conv2d_83 (Conv2D)             (None, 256, 256, 3)  165         ['concatenate_54[0][0]']
#
#  concatenate_56 (Concatenate)   (None, 256, 256, 41  0           ['conv2d_81[0][0]',
#                                 )                                 'conv2d_82[0][0]',
#                                                                   'conv2d_83[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  conv2d_84 (Conv2D)             (None, 256, 256, 3)  1110        ['concatenate_56[0][0]']
#
#  up_sampling2d_6 (UpSampling2D)  (None, 512, 512, 3)  0          ['conv2d_84[0][0]']
#
# ==================================================================================================
# Total params: 22,702,429
# Trainable params: 22,702,423
# Non-trainable params: 6
# __________________________________________________________________________________________________

# %% [markdown]
# ## 5 Layer

# %%
input_layer = Input((512,512,3))
e1 = encoder_block(input_layer,32)
e2 = encoder_block(e1,64)
e3 = encoder_block(e2,128)
e4 = encoder_block(e3,256)
e5 = encoder_block(e4,512)
b = bottleneck(e5)
d1 = decoder_block(b,e5,256)
d2 = decoder_block(d1,e4,256)
d3 = decoder_block(d2,e3,128)
d4 = decoder_block(d3,e2,64)
d5 = decoder_block(d4,e1,3)

CR_Net = Model(inputs = input_layer, outputs = d5)
CR_Net.summary()
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_3 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_6 (Conv2D)              (None, 512, 512, 32  896         ['input_3[0][0]']
#                                 )
#
#  conv2d_7 (Conv2D)              (None, 512, 512, 32  2432        ['input_3[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 512, 512, 32  4736        ['input_3[0][0]']
#                                 )
#
#  concatenate_1 (Concatenate)    (None, 512, 512, 64  0           ['conv2d_6[0][0]',
#                                 )                                 'conv2d_7[0][0]']
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 64  0           ['conv2d_6[0][0]',
#                                 )                                 'conv2d_8[0][0]']
#
#  concatenate_2 (Concatenate)    (None, 512, 512, 64  0           ['conv2d_7[0][0]',
#                                 )                                 'conv2d_8[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 512, 512, 32  18464       ['concatenate_1[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 512, 512, 32  18464       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 512, 512, 32  18464       ['concatenate_2[0][0]']
#                                 )
#
#  concatenate_4 (Concatenate)    (None, 512, 512, 96  0           ['conv2d_9[0][0]',
#                                 )                                 'conv2d_10[0][0]',
#                                                                   'conv2d_11[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 512, 512, 32  27680       ['concatenate_4[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 32  0           ['conv2d_12[0][0]']
#                                 )
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 64  18496       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 64  51264       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 256, 256, 64  100416      ['max_pooling2d[0][0]']
#                                 )
#
#  concatenate_5 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_13[0][0]',
#                                 8)                                'conv2d_14[0][0]']
#
#  concatenate_7 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_13[0][0]',
#                                 8)                                'conv2d_15[0][0]']
#
#  concatenate_6 (Concatenate)    (None, 256, 256, 12  0           ['conv2d_14[0][0]',
#                                 8)                                'conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_5[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_7[0][0]']
#                                 )
#
#  conv2d_18 (Conv2D)             (None, 256, 256, 64  73792       ['concatenate_6[0][0]']
#                                 )
#
#  concatenate_8 (Concatenate)    (None, 256, 256, 19  0           ['conv2d_16[0][0]',
#                                 2)                                'conv2d_17[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 256, 256, 64  110656      ['concatenate_8[0][0]']
#                                 )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 64  0          ['conv2d_19[0][0]']
#                                 )
#
#  conv2d_20 (Conv2D)             (None, 128, 128, 12  73856       ['max_pooling2d_1[0][0]']
#                                 8)
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 12  204928      ['max_pooling2d_1[0][0]']
#                                 8)
#
#  conv2d_22 (Conv2D)             (None, 128, 128, 12  401536      ['max_pooling2d_1[0][0]']
#                                 8)
#
#  concatenate_9 (Concatenate)    (None, 128, 128, 25  0           ['conv2d_20[0][0]',
#                                 6)                                'conv2d_21[0][0]']
#
#  concatenate_11 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_20[0][0]',
#                                 6)                                'conv2d_22[0][0]']
#
#  concatenate_10 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_21[0][0]',
#                                 6)                                'conv2d_22[0][0]']
#
#  conv2d_23 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_9[0][0]']
#                                 8)
#
#  conv2d_24 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_11[0][0]']
#                                 8)
#
#  conv2d_25 (Conv2D)             (None, 128, 128, 12  295040      ['concatenate_10[0][0]']
#                                 8)
#
#  concatenate_12 (Concatenate)   (None, 128, 128, 38  0           ['conv2d_23[0][0]',
#                                 4)                                'conv2d_24[0][0]',
#                                                                   'conv2d_25[0][0]']
#
#  conv2d_26 (Conv2D)             (None, 128, 128, 12  442496      ['concatenate_12[0][0]']
#                                 8)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 128)  0          ['conv2d_26[0][0]']
#
#  conv2d_27 (Conv2D)             (None, 64, 64, 256)  295168      ['max_pooling2d_2[0][0]']
#
#  conv2d_28 (Conv2D)             (None, 64, 64, 256)  819456      ['max_pooling2d_2[0][0]']
#
#  conv2d_29 (Conv2D)             (None, 64, 64, 256)  1605888     ['max_pooling2d_2[0][0]']
#
#  concatenate_13 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_27[0][0]',
#                                                                   'conv2d_28[0][0]']
#
#  concatenate_15 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_27[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  concatenate_14 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_28[0][0]',
#                                                                   'conv2d_29[0][0]']
#
#  conv2d_30 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_13[0][0]']
#
#  conv2d_31 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_15[0][0]']
#
#  conv2d_32 (Conv2D)             (None, 64, 64, 256)  1179904     ['concatenate_14[0][0]']
#
#  concatenate_16 (Concatenate)   (None, 64, 64, 768)  0           ['conv2d_30[0][0]',
#                                                                   'conv2d_31[0][0]',
#                                                                   'conv2d_32[0][0]']
#
#  conv2d_33 (Conv2D)             (None, 64, 64, 256)  1769728     ['concatenate_16[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 256)  0          ['conv2d_33[0][0]']
#
#  conv2d_34 (Conv2D)             (None, 32, 32, 512)  1180160     ['max_pooling2d_3[0][0]']
#
#  conv2d_35 (Conv2D)             (None, 32, 32, 512)  3277312     ['max_pooling2d_3[0][0]']
#
#  conv2d_36 (Conv2D)             (None, 32, 32, 512)  6423040     ['max_pooling2d_3[0][0]']
#
#  concatenate_17 (Concatenate)   (None, 32, 32, 1024  0           ['conv2d_34[0][0]',
#                                 )                                 'conv2d_35[0][0]']
#
#  concatenate_19 (Concatenate)   (None, 32, 32, 1024  0           ['conv2d_34[0][0]',
#                                 )                                 'conv2d_36[0][0]']
#
#  concatenate_18 (Concatenate)   (None, 32, 32, 1024  0           ['conv2d_35[0][0]',
#                                 )                                 'conv2d_36[0][0]']
#
#  conv2d_37 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate_17[0][0]']
#
#  conv2d_38 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate_19[0][0]']
#
#  conv2d_39 (Conv2D)             (None, 32, 32, 512)  4719104     ['concatenate_18[0][0]']
#
#  concatenate_20 (Concatenate)   (None, 32, 32, 1536  0           ['conv2d_37[0][0]',
#                                 )                                 'conv2d_38[0][0]',
#                                                                   'conv2d_39[0][0]']
#
#  conv2d_40 (Conv2D)             (None, 32, 32, 512)  7078400     ['concatenate_20[0][0]']
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 16, 16, 512)  0          ['conv2d_40[0][0]']
#
#  conv2d_41 (Conv2D)             (None, 16, 16, 512)  2359808     ['max_pooling2d_4[0][0]']
#
#  conv2d_42 (Conv2D)             (None, 16, 16, 512)  2359808     ['conv2d_41[0][0]']
#
#  multi_head_attention (MultiHea  (None, 16, 16, 512)  18971      ['max_pooling2d_4[0][0]',
#  dAttention)                                                      'conv2d_42[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 16, 16, 512)  2048       ['multi_head_attention[0][0]']
#  rmalization)
#
#  dropout (Dropout)              (None, 16, 16, 512)  0           ['batch_normalization_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 256)  1179904    ['dropout[0][0]']
#  ose)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 16, 16, 256)  3277056    ['dropout[0][0]']
#  spose)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 16, 16, 256)  6422784    ['dropout[0][0]']
#  spose)
#
#  concatenate_21 (Concatenate)   (None, 16, 16, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_transpose_1[0][0]']
#
#  concatenate_23 (Concatenate)   (None, 16, 16, 512)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_transpose_2[0][0]']
#
#  concatenate_22 (Concatenate)   (None, 16, 16, 512)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_transpose_2[0][0]']
#
#  conv2d_43 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate_21[0][0]']
#
#  conv2d_44 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate_23[0][0]']
#
#  conv2d_45 (Conv2D)             (None, 16, 16, 256)  1179904     ['concatenate_22[0][0]']
#
#  concatenate_24 (Concatenate)   (None, 16, 16, 1280  0           ['conv2d_43[0][0]',
#                                 )                                 'conv2d_44[0][0]',
#                                                                   'conv2d_45[0][0]',
#                                                                   'max_pooling2d_4[0][0]']
#
#  conv2d_46 (Conv2D)             (None, 16, 16, 256)  2949376     ['concatenate_24[0][0]']
#
#  up_sampling2d (UpSampling2D)   (None, 32, 32, 256)  0           ['conv2d_46[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 32, 32, 256)  590080     ['up_sampling2d[0][0]']
#  spose)
#
#  conv2d_transpose_4 (Conv2DTran  (None, 32, 32, 256)  1638656    ['up_sampling2d[0][0]']
#  spose)
#
#  conv2d_transpose_5 (Conv2DTran  (None, 32, 32, 256)  3211520    ['up_sampling2d[0][0]']
#  spose)
#
#  concatenate_25 (Concatenate)   (None, 32, 32, 512)  0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_transpose_4[0][0]']
#
#  concatenate_27 (Concatenate)   (None, 32, 32, 512)  0           ['conv2d_transpose_3[0][0]',
#                                                                   'conv2d_transpose_5[0][0]']
#
#  concatenate_26 (Concatenate)   (None, 32, 32, 512)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'conv2d_transpose_5[0][0]']
#
#  conv2d_47 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_25[0][0]']
#
#  conv2d_48 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_27[0][0]']
#
#  conv2d_49 (Conv2D)             (None, 32, 32, 256)  1179904     ['concatenate_26[0][0]']
#
#  concatenate_28 (Concatenate)   (None, 32, 32, 1024  0           ['conv2d_47[0][0]',
#                                 )                                 'conv2d_48[0][0]',
#                                                                   'conv2d_49[0][0]',
#                                                                   'max_pooling2d_3[0][0]']
#
#  conv2d_50 (Conv2D)             (None, 32, 32, 256)  2359552     ['concatenate_28[0][0]']
#
#  up_sampling2d_1 (UpSampling2D)  (None, 64, 64, 256)  0          ['conv2d_50[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 64, 64, 128)  295040     ['up_sampling2d_1[0][0]']
#  spose)
#
#  conv2d_transpose_7 (Conv2DTran  (None, 64, 64, 128)  819328     ['up_sampling2d_1[0][0]']
#  spose)
#
#  conv2d_transpose_8 (Conv2DTran  (None, 64, 64, 128)  1605760    ['up_sampling2d_1[0][0]']
#  spose)
#
#  concatenate_29 (Concatenate)   (None, 64, 64, 256)  0           ['conv2d_transpose_6[0][0]',
#                                                                   'conv2d_transpose_7[0][0]']
#
#  concatenate_31 (Concatenate)   (None, 64, 64, 256)  0           ['conv2d_transpose_6[0][0]',
#                                                                   'conv2d_transpose_8[0][0]']
#
#  concatenate_30 (Concatenate)   (None, 64, 64, 256)  0           ['conv2d_transpose_7[0][0]',
#                                                                   'conv2d_transpose_8[0][0]']
#
#  conv2d_51 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_29[0][0]']
#
#  conv2d_52 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_31[0][0]']
#
#  conv2d_53 (Conv2D)             (None, 64, 64, 128)  295040      ['concatenate_30[0][0]']
#
#  concatenate_32 (Concatenate)   (None, 64, 64, 512)  0           ['conv2d_51[0][0]',
#                                                                   'conv2d_52[0][0]',
#                                                                   'conv2d_53[0][0]',
#                                                                   'max_pooling2d_2[0][0]']
#
#  conv2d_54 (Conv2D)             (None, 64, 64, 128)  589952      ['concatenate_32[0][0]']
#
#  up_sampling2d_2 (UpSampling2D)  (None, 128, 128, 12  0          ['conv2d_54[0][0]']
#                                 8)
#
#  conv2d_transpose_9 (Conv2DTran  (None, 128, 128, 64  73792      ['up_sampling2d_2[0][0]']
#  spose)                         )
#
#  conv2d_transpose_10 (Conv2DTra  (None, 128, 128, 64  204864     ['up_sampling2d_2[0][0]']
#  nspose)                        )
#
#  conv2d_transpose_11 (Conv2DTra  (None, 128, 128, 64  401472     ['up_sampling2d_2[0][0]']
#  nspose)                        )
#
#  concatenate_33 (Concatenate)   (None, 128, 128, 12  0           ['conv2d_transpose_9[0][0]',
#                                 8)                                'conv2d_transpose_10[0][0]']
#
#  concatenate_35 (Concatenate)   (None, 128, 128, 12  0           ['conv2d_transpose_9[0][0]',
#                                 8)                                'conv2d_transpose_11[0][0]']
#
#  concatenate_34 (Concatenate)   (None, 128, 128, 12  0           ['conv2d_transpose_10[0][0]',
#                                 8)                                'conv2d_transpose_11[0][0]']
#
#  conv2d_55 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_33[0][0]']
#                                 )
#
#  conv2d_56 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_35[0][0]']
#                                 )
#
#  conv2d_57 (Conv2D)             (None, 128, 128, 64  73792       ['concatenate_34[0][0]']
#                                 )
#
#  concatenate_36 (Concatenate)   (None, 128, 128, 25  0           ['conv2d_55[0][0]',
#                                 6)                                'conv2d_56[0][0]',
#                                                                   'conv2d_57[0][0]',
#                                                                   'max_pooling2d_1[0][0]']
#
#  conv2d_58 (Conv2D)             (None, 128, 128, 64  147520      ['concatenate_36[0][0]']
#                                 )
#
#  up_sampling2d_3 (UpSampling2D)  (None, 256, 256, 64  0          ['conv2d_58[0][0]']
#                                 )
#
#  conv2d_transpose_12 (Conv2DTra  (None, 256, 256, 3)  1731       ['up_sampling2d_3[0][0]']
#  nspose)
#
#  conv2d_transpose_13 (Conv2DTra  (None, 256, 256, 3)  4803       ['up_sampling2d_3[0][0]']
#  nspose)
#
#  conv2d_transpose_14 (Conv2DTra  (None, 256, 256, 3)  9411       ['up_sampling2d_3[0][0]']
#  nspose)
#
#  concatenate_37 (Concatenate)   (None, 256, 256, 6)  0           ['conv2d_transpose_12[0][0]',
#                                                                   'conv2d_transpose_13[0][0]']
#
#  concatenate_39 (Concatenate)   (None, 256, 256, 6)  0           ['conv2d_transpose_12[0][0]',
#                                                                   'conv2d_transpose_14[0][0]']
#
#  concatenate_38 (Concatenate)   (None, 256, 256, 6)  0           ['conv2d_transpose_13[0][0]',
#                                                                   'conv2d_transpose_14[0][0]']
#
#  conv2d_59 (Conv2D)             (None, 256, 256, 3)  165         ['concatenate_37[0][0]']
#
#  conv2d_60 (Conv2D)             (None, 256, 256, 3)  165         ['concatenate_39[0][0]']
#
#  conv2d_61 (Conv2D)             (None, 256, 256, 3)  165         ['concatenate_38[0][0]']
#
#  concatenate_40 (Concatenate)   (None, 256, 256, 41  0           ['conv2d_59[0][0]',
#                                 )                                 'conv2d_60[0][0]',
#                                                                   'conv2d_61[0][0]',
#                                                                   'max_pooling2d[0][0]']
#
#  conv2d_62 (Conv2D)             (None, 256, 256, 3)  1110        ['concatenate_40[0][0]']
#
#  up_sampling2d_4 (UpSampling2D)  (None, 512, 512, 3)  0          ['conv2d_62[0][0]']
#
# ==================================================================================================
# Total params: 81,458,217
# Trainable params: 81,457,193
# Non-trainable params: 1,024
# __________________________________________________________________________________________________

# %% [markdown]
# # GAN Defintion

# %%
# define the combined generator and discriminator model, for updating the generator
def define_gan(g_model, d_model, image_shape):
	# make weights in the discriminator not trainable
	for layer in d_model.layers:
		if not isinstance(layer, BatchNormalization):
			layer.trainable = False
	# define the source image
	in_src = Input(shape=image_shape)
	# connect the source image to the generator input
	gen_out = g_model(in_src)
	# connect the source input and generator output to the discriminator input
	dis_out = d_model([in_src, gen_out])
	# src image as input, generated image and classification output
	model = Model(in_src, [dis_out, gen_out])
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss=['binary_crossentropy','mae'], optimizer=opt, loss_weights=[1,100], metrics=[psnr,ssim,tf.keras.losses.mean_squared_error])
	return model

# %%
image_shape = (512,512,3)
# define the models
d_model = define_discriminator(image_shape)
g_model = CR_Net
#g_model.load_weights('C:/Users/ArrunPersonal/Codes/ISRO_GAN/RUNet.h5')
# define the composite model
gan_model = define_gan(g_model, d_model, image_shape)
# summarize the model
gan_model.summary()
# plot the model
#K.utils.plot_model(gan_model, to_file='gan_model_plot.png', show_shapes=True, show_layer_names=True)

# %% [markdown]
# # Aiding functions

# %%
def generate_real_samples(dataset, n_samples, patch_shape):
	# unpack dataset
	trainA, trainB = dataset
	# choose random instances
	ix = np.random.randint(0, trainA.shape[0], n_samples)
	# retrieve selected images
	X1, X2 = trainA[ix], trainB[ix]
	# generate 'real' class labels (1)
	y = np.ones((n_samples, patch_shape, patch_shape, 1))
	return [X1, X2], y

# %%
def generate_fake_samples(g_model, samples, targets, patch_shape):
	# generate fake instance
	X = g_model.predict(samples)
	#plt.imshow(X[0])
	#print("PSNR: ", psnr_np(samples, X))
	# create 'fake' class labels (0)
	y = np.zeros((len(X), patch_shape, patch_shape, 1))
	return X, y

# %% [markdown]
# # Train GAN

# %%
# train pix2pix models
def train(d_model, g_model, gan_model, train_dataset, test_dataset, max_psnr = 20, max_ssim = 0.80, n_epochs=60, n_batch=batch_size, n_patch=32):
    # calculate the number of batches per training epoch
    bat_per_epo = batch_size
    # calculate the number of training iterations
    n_steps = bat_per_epo * n_epochs
    psnr_tot = 0
    msee_tot = 0
    ssim_tot = 0
    psnr_tot_2 = 0
    msee_tot_2 = 0
    ssim_tot_2 = 0
    trloss = 0
    teloss=0
    n_steps = int(400//n_batch)
    # manually enumerate epochs
    for i in range(n_epochs):
        psnr_tot = 0
        msee_tot = 0
        ssim_tot = 0
        psnr_tot_2 = 0
        msee_tot_2 = 0
        ssim_tot_2 = 0
        q1_tot = 0
        q2_tot = 0
        q3_tot = 0
        q1_tot_2 = 0
        q2_tot_2 = 0
        q3_tot_2 = 0
        trloss = 0
        teloss=0
        print("Epoch: ", i+1)

        for j in range((n_steps)):
        # select a batch of real samples
            [X_realA, X_realB], y_real = generate_real_samples(train_dataset, n_batch, n_patch)

            # generate a batch of fake samples
            X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, X_realB, n_patch)
            #break
            # update discriminator for real samples
            d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)
            # update discriminator for generated samples
            d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)
            # update the generator
            #g_loss, psnr, ssim, msee, xd, ab, bc, cd, de = gan_model.train_on_batch(X_realA, [y_real, X_realB])
            g_loss, _, _,q1, q2, q3, psnr, ssim, msee  = gan_model.train_on_batch(X_realA, [y_real, X_realB])

            [X_realA_test, X_realB_test], y_real_test = generate_real_samples(test_dataset, n_batch, n_patch)
            g_loss_2, _, _,q1_2, q2_2, q3_2, psnr_2, ssim_2, msee_2  = gan_model.test_on_batch(X_realA_test, [y_real_test, X_realB_test])
            #tr = gan_model.train_on_batch(X_realA, [y_real, X_realB])
            #te = gan_model.test_on_batch(X_realA, [y_real, X_realB])
            psnr_tot+=psnr
            msee_tot+=msee
            ssim_tot+=ssim
            psnr_tot_2+=psnr_2
            msee_tot_2+=msee_2
            ssim_tot_2+=ssim_2
            trloss+=g_loss
            teloss+=g_loss_2
            q1_tot+=q1
            q2_tot+=q2
            q3_tot+=q3
            q1_tot_2+=q1_2
            q2_tot_2+=q2_2
            q3_tot_2+=q3_2
            print('\t >%d, d1[%.3f] d2[%.3f] g[%.3f]' % (j+1, d_loss1, d_loss2, g_loss))

        print("\n\t\tTrain\n\tLoss: ", trloss, "PSNR: ", psnr_tot/n_steps, "SSIM: ", ssim_tot/n_steps, "MSE: ", msee_tot/n_steps, f' q1: {q1_tot/n_steps}, q2:{q2_tot/n_steps}, q3:{q3_tot/n_steps}\n')
        print("\t\tTest\n\tLoss: ", teloss, "PSNR: ", psnr_tot_2/n_steps, "SSIM: ", ssim_tot_2/n_steps, "MSE: ", msee_tot_2/n_steps, f' q1: {q1_tot_2/n_steps}, q2:{q2_tot_2/n_steps}, q3:{q3_tot_2/n_steps}\n')
        #ssim_tot_2, psnr_tot_2 = custom_test(test_dataset)

        if (psnr_tot_2 > max_psnr):
            ## For RICE 1
            g_model.save_weights('C:/Users/ArrunPersonal/Codes/ISRO_GAN/PostComments_NewWeights/RICE1_weights/RS_CloudGAN_l5_k357_selfattn_bce_max_psnr_rice1.h5')
            ## For RICE 2
            #g_model.save_weights('C:/Users/ArrunPersonal/Codes/ISRO_GAN/PostComments_NewWeights/RICE2_weights/RS_CloudGAN_l3_k7911_max_psnr_rice2.h5')
            max_psnr = psnr_tot_2
            print("\n ------------\nSaved psnr model \n------------------")
            
        if (ssim_tot_2 > max_ssim):
            ## For RICE 1
            g_model.save_weights('C:/Users/ArrunPersonal/Codes/ISRO_GAN/PostComments_NewWeights/RICE1_weights/RS_CloudGAN_l5_k357_selfattn_bce_max_ssim_rice1.h5')
            ## For RICE 2
            #g_model.save_weights('C:/Users/ArrunPersonal/Codes/ISRO_GAN/PostComments_NewWeights/RICE2_weights/RS_CloudGAN_l3_k7911_max_ssim_rice2.h5')
            max_ssim = ssim_tot_2
            print("\n ------------\nSaved ssim model \n------------------")
    return max_psnr, max_ssim

# %%
max_psnr_g, max_ssim_g = train(d_model, g_model, gan_model, train_data, val_data)
